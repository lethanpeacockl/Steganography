# %%
import matplotlib.pyplot as plt
import PIL.Image as img
import numpy as np

# %%
# read in test image
plot_img = img.open("Methods/image_file_analysis/plot_channels.jpg")

# %%
# display image dimensions
plot_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x875 at 0x131D82440>

# %%
# convert to matrix
img_arr = np.array(plot_img)

# %%
img_arr.shape
# Out:
# (875, 750, 3)

# %%
print("jpg only 3 channels")
# Out:
# jpg only 3 channels

# %%
#extract rgb channels
red = img_arr[:,:,0]
green = img_arr[:,:,1]
blue = img_arr[:,:,2]

# %%
# reshape rgb  matrixs to 1d  vector
red = red.ravel()
green = green.ravel()
blue = blue.ravel()


# get x axis
x_axis = [x for x in range(len(red))]

# %%
# plot channels
plt.plot(x_axis, red, label='red')
plt.plot(x_axis, green, label='green')
plt.plot(x_axis, blue , label='blue')

plt.show()

# %%
print("i think lots of 0? values causing density issue for eyes and resolution of plot")
# Out:
# i think lots of 0? values causing density issue for eyes and resolution of plot

# %%
# reduce to first 50 pixels
red = red[:50]
green = green[:50]
blue = blue[:50]
x_axis = x_axis[:50]

# plot channels
plt.plot(x_axis, red, 'r', label='red')
plt.plot(x_axis, green, 'g', label='green')
plt.plot(x_axis, blue, 'b', label='blue')

plt.legend()
plt.show()

# %%
this thpe of cisualization and then processing could detect spikes as deviations from consistent color change in large resolution images by segmenting out large wuantities of an image based off k means to donthe segmentstion 

if a k means area was segmented and fhen indicidual signals processed sudden spikes could indicate tampering
# Out:
#   File "<ipython-input-43-80b1f11131a0>", line 1
#     this thpe of cisualization and then processing could detect spikes as deviations from consistent color change in large resolution images by segmenting out large wuantities of an image based off k means to donthe segmentstion
#          ^
# SyntaxError: invalid syntax
